# %% [markdown]
# # Классификация текстов с использованием Наивного Байесовского Классификатора

# %% [markdown]
# ## Задание 1 (1 балл)

# %% [markdown]
# Откройте данные. Узнайте, сколько в них спам- и не спам-писем. Визуализируйте полученные соотношение подходящим образом.

# %%
# откройте данные: ваш код здесь
import numpy as np
import pandas as pd
df = pd.read_csv('spam_or_not_spam.csv', sep=',')
df.head()
# Out:
#                                                email  label
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0
# 1  martin a posted tassos papadopoulos the greek ...      0
# 2  man threatens explosion in moscow thursday aug...      0
# 3  klez the virus that won t die already the most...      0
# 4   in adding cream to spaghetti carbonara which ...      0

# %%
# рассчитайте частоты для классов : ваш код здесь
df['label'].value_counts()
# Out:
# label
# 0    2500
# 1     500
# Name: count, dtype: int64

# %%
# визуализируйте результат: ваш код здесь
df_clean = df.copy()
df_clean['email'] = df_clean['email'].str.replace('\W+', ' ', regex=True)

df_clean['email'] = df_clean['email'].str.replace('\s+', ' ', regex=True).str.strip()
df_clean['email']= df_clean['email'].str.lower()
df_clean['email'] = df_clean['email'].str.split()

df_clean['label'].value_counts() / df_clean.shape[0] * 100
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Denlex\AppData\Local\Temp\ipykernel_1528\3627352383.py:3: SyntaxWarning: invalid escape sequence '\W'
#   df_clean['email'] = df_clean['email'].str.replace('\W+', ' ', regex=True)
# C:\Users\Denlex\AppData\Local\Temp\ipykernel_1528\3627352383.py:5: SyntaxWarning: invalid escape sequence '\s'
#   df_clean['email'] = df_clean['email'].str.replace('\s+', ' ', regex=True).str.strip()
# label
# 0    83.333333
# 1    16.666667
# Name: count, dtype: float64

# %% [markdown]
# ## Задание 2 (2 балла)

# %% [markdown]
# Вам необходимо предобработать ваши данные и перевести их в векторный вид. Подгрузим необходимый модуль:

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Замените в данных все пустые строки и строки, состоящие из пробелов, на пропуски (NaN). После этого удалите из данных все строки, в которых наблюдаются пропущенные значения.

# %%
#ваш код здесь
# Замена пустых строк и строк только с пробелами на NaN
df = df.replace(r'^\s*$', pd.NA, regex=True)

# Удаление строк с пропущенными значениями
df = df.dropna()

# Проверка результата
print(f"Размер данных после очистки: {df.shape}")
print(df.head())
# Out:
# Размер данных после очистки: (2997, 2)
#                                                email  label
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0
# 1  martin a posted tassos papadopoulos the greek ...      0
# 2  man threatens explosion in moscow thursday aug...      0
# 3  klez the virus that won t die already the most...      0
# 4   in adding cream to spaghetti carbonara which ...      0

# %% [markdown]
# Переводим данные в векторный вид:

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df["email"])

# %% [markdown]
# Определите, сколько теперь признаков в нашем наборе данных:

# %%
#ваш код здесь
y = df["label"]
print(X.shape, y.shape)
# Out:
# (2997, 34116) (2997,)

# %% [markdown]
# ## Задание 3 (2 балла)

# %% [markdown]
# Определите целевую переменную и признаки:

# %%
#ваш код здесь

# %% [markdown]
# Разделите выборку на обучающую и тестовую, используя стратифицированное разбиение (параметр `stratify` установите в значение вектора ответов y) размер тестовой выборки (`test_size`) возьмите как 0.25, параметр `random_state` определите со значением 42:

# %%
#ваш код здесь
from sklearn.model_selection import train_test_split

# Разделение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    train_size=0.75, 
    test_size=0.25, 
    stratify=y, 
    random_state=42
)

# Вычисление среднего значения целевой переменной для тестовой выборки
test_mean = y_test.mean()

# Округление до третьего знака после запятой
result = round(test_mean, 3)

print(f"Среднее значение целевой переменной для тестовой выборки: {result}")
# Out:
# Среднее значение целевой переменной для тестовой выборки: 0.165

# %% [markdown]
# Рассчитайте среднее значение целевой переменной по тестовой выборке:

# %%
#ваш код здесь

# %% [markdown]
# ## Задание 4 (3 балла)

# %% [markdown]
# Определите и обучите подходящий алгоритм с параметром alpha = 0.01

# %%
#ваш код здесь

# %% [markdown]
# Оцените результат с точки зрения всех известных вам метрик (не менее трёх):

# %%
#ваш код здесь

# %% [markdown]
# Нарисуйте ROC-кривую:

# %%
#ваш код здесь

# %% [markdown]
# ## Задание 5 (3 балла)

# %% [markdown]
# Переберите несколько значений alpha с помощью кросс-валидации. Оцените, зависит ли от этого параметра качество классификации.

# %%
#ваш код здесь
